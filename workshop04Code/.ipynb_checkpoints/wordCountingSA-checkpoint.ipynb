# %% [markdown]
# ## COSC2671 Social Media and Network Analytics
#
# ## Workshop 4
#
# Jeffrey Chan, RMIT University, 2022

# %%
# importing packages and nltk data libraries
import string
import json
import codecs
import re

import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')

from colorama import Fore, Back, Style
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\lukas\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# load the twitter processing python class for use
# for those code that we repeatingly use but doesn't change much, or only change due to input, it is good to write them as
# functions and call later, which we are doing here.
# As the weeks goes by, we will increasingly do and make use of the benefits of scripts but also the interactivity of
# interactive Jupyter notebooks
# %load_ext autoreload
# %autoreload 1

# we are importing TwitterProcessing.py and its contents
# %aimport TwitterProcessing
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# countWordSentimentAnalysis(): First approach for unsupervised sentiment analysis.
#
# Complete the parts with TODO for the workshop.

# %%
def loadWords(filename):
    words=[]
    with open(filename, 'r') as f:
        for line in f:
            words.append(f)

    return words


def countWords(tweetText, wordsToCount):
    print(tweetText)

    wordCount = 0
    for word in tweetText:
        if word in wordsToCount:
            wordCount += 1
    return wordCount


def countWordSentimentAnalysis(setPosWords, setNegWords, sTweetsFilename, bPrint, tweetProcessor):
    """
    Basic sentiment analysis.  Count the number of positive words, count the negative words, overall polarity is the
    difference in the two numbers.

    @param setPosWords: set of positive sentiment words
    @param setNegWords: set of negative sentiment words
    @param sTweetsFilename: name of input file containing a json formated tweet dump
    @param bPrint: whether to print the stream of tokens and sentiment.  Uses colorama to highlight sentiment words.
    @param tweetProcessor: TweetProcessing object, used to pre-process each tweet.

    @returns: list of tweets, in the format of [date, sentiment]
    """

    lSentiment = []
    # open file and process tweets, one by one
    with open(sTweetsFilename, 'r') as f:
        
        # Note that this is using the older data format, but same ideas still apply
        for line in f:
            # each line is loaded according to json format, into tweet, which is actually a dictionary
            tweet = json.loads(line)
            
            try:
                tweetText = tweet.get('text', '')
                tweetDate = tweet.get('created_at')
                # pre-process the tweet text
                lTokens = tweetProcessor.process(tweetText)

                # Compute sentiment value
                numberPosWords = countWords(lTokens, setPosWords)
                numberNegWords = countWords(lTokens, setNegWords)
                sentiment =  numberPosWords - numberNegWords

                # save the date and sentiment of each tweet (used for time series)
                lSentiment.append([pd.to_datetime(tweetDate), sentiment])

                # if we are printing, each token is printed and coloured according to red if positive word, and blue
                # if negative
                if bPrint:
                    for token in lTokens:
                        if token in setPosWords:
                            print(Fore.RED + token + ', ', end='')
                        elif token in setNegWords:
                            print(Fore.BLUE + token + ', ', end='')
                        else:
                            print(Style.RESET_ALL + token + ', ', end='')

                    print(': {}'.format(sentiment))


            except KeyError as e:
                pass

    return lSentiment

# %% [markdown]
# vaderSentimentAnalysis(): Second approach for unsupervised sentiment analysis.

# %%
def vaderSentimentAnalysis(sTweetsFilename, bPrint, tweetProcessor):
    """
    Use Vader lexicons instead of a raw positive and negative word count.

    @param sTweetsFilename: name of input file containing a json formated tweet dump
    @param bPrint: whether to print the stream of tokens and sentiment.  Uses colorama to highlight sentiment words.
    @param tweetProcessor: TweetProcessing object, used to pre-process each tweet.

    @returns: list of tweets, in the format of [date, sentiment]
    """

    # this is the vader sentiment analyser, part of nltk
    sentAnalyser = SentimentIntensityAnalyzer()


    lSentiment = []
    # open file and process tweets, one by one
    with open(sTweetsFilename, 'r') as f:
        for line in f:
            # each line is loaded according to json format, into tweet, which is actually a dictionary
            tweet = json.loads(line)

            try:
                tweetText = tweet.get('text', '')
                tweetDate = tweet.get('created_at')
                # pre-process the tweet text
#                 lTokens = tweetProcessor.process(tweetText)

                # this computes the sentiment scores (called polarity score in nltk, but mean same thing essentially)
                # see lab sheet for what dSentimentScores holds
#                 dSentimentScores = sentAnalyser.polarity_scores(" ".join(lTokens))
                dSentimentScores = sentAnalyser.polarity_scores(tweetText)


                # save the date and sentiment of each tweet (used for time series)
                lSentiment.append([pd.to_datetime(tweetDate), dSentimentScores['compound']])

                # if we are printing, we print the tokens then the sentiment scores.  Because we don't have the list
                # of positive and negative words, we cannot use colorama to label each token
                if bPrint:
#                     print(*lTokens, sep=', ')
                    # uncomment this (and comment above line) if you are analysing the tweets directly, instead of the tokens
                    print(tweetText)
                    for cat,score in dSentimentScores.items():
                        print('{0}: {1}, '.format(cat, score), end='')
                    print()

            except KeyError as e:
                pass


    return lSentiment

# %% [markdown]
# Following code will run the approaches.
#
# First we set the parameters.

# %%
# arguments for this notebook
# modify as needed if you want to do similar analaysis for other purposes

# input file of set of postive words
posWordFile = 'positive-words.txt'
# input file of set of negative words
negWordFile = 'negative-words.txt'
# input file of set of tweets (json format)
tweetsFile = 'rmitCsTwitterTimeline.json'
# flag to determine whether to print out tweets and their sentiment
flagPrint = True
# specify the approach to take, one of [count, vader]
# change this to use a different sentiment approach
approach = 'vader'

# %% [markdown]
# Then following calls the functions we have written above.  First do the pre-processing, then calls the functions to do the sentiment analysis.

# %%
"""
This is the main part of the notebook, that will can and run the various methods defined before.
"""


# construct the tweet pro-processing object
tweetTokenizer = TweetTokenizer()
lPunct = list(string.punctuation)
# standard 'English' stopwords plus we want to remove things like 'rt' (retweet) etc
lStopwords = stopwords.words('english') + lPunct + ['rt', 'via', '...', '…', '"', "'", '`']

# call the TwitterProcessing python script
tweetProcessor = TwitterProcessing.TwitterProcessing(tweetTokenizer, lStopwords)


# load set of positive words
lPosWords = []
with open(posWordFile, 'r', encoding='utf-8', errors='ignore') as fPos:
    for sLine in fPos:
        lPosWords.append(sLine.strip())

setPosWords = set(lPosWords)


# load set of negative words
lNegWords = []
with codecs.open(negWordFile, 'r', encoding='utf-8', errors='ignore') as fNeg:
    for sLine in fNeg:
        lNegWords.append(sLine.strip())

setNegWords = set(lNegWords)

# %%
# compute the sentiment
# to change method, update parameter settings, particularly the variable 'approach' and rerun the parameter setting cell,
# and also this cell
lSentiment = []
if approach == 'count':
    lSentiment = countWordSentimentAnalysis(setPosWords, setNegWords, tweetsFile, flagPrint, tweetProcessor)
elif approach == 'vader':
    lSentiment = vaderSentimentAnalysis(tweetsFile, flagPrint, tweetProcessor)
# Out:
# Google trains #machinelearning #algorithm to use eyes to learn about the heart - MedCity News https://t.co/V0A6ADfwPh
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 12 Algorithms Every Data Scientist Should Know https://t.co/2F1Tk2Nnd2
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 10th International Micro Air Vehicle Competition &amp; Conference (#IMAV2018) to be held at @RMIT this year!... https://t.co/pB3Py9rGLU
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 10th International Micro Air Vehicle Competition &amp; Conference (#IMAV2018) to be held at @RMIT this year! Register h… https://t.co/Y1ecHwswNR
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Hungry Bear is your go-to for tasty pizza with sourdough bases and delicious toppings:  https://t.co/TeFCCSJ8KK https://t.co/v38cRDx4hP
# neg: 0.0, neu: 0.802, pos: 0.198, compound: 0.5719,
# Notes from Shenzhen — the next Greater Bay Area https://t.co/wtAp1mAeEg
# neg: 0.0, neu: 0.762, pos: 0.238, compound: 0.3612,
# RT @jblefevre60: By 2025, #DigitalTransformation aims to complete reshape #FinServ w/ #BigData and #Robotic Process #Automation taking cent…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Why #API is the future of insurance, as it's the tech part required to develop ecosystems of tech/startups around y… https://t.co/bZrdLU8JJv
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Two Swiss institutions top the list of universities with the strongest global connections
# https://t.co/usByqczIr9
# neg: 0.0, neu: 0.719, pos: 0.281, compound: 0.5719,
# Check out my new #freebook on Amazon! Truth, Lies and #Statistics  https://t.co/GHdTLnDFn3 https://t.co/EdojdxRN0I
# neg: 0.164, neu: 0.585, pos: 0.251, compound: 0.126,
# Caterina Fake on turning down VC roles a decade ago: ‘I just kind of didn’t fit in’ https://t.co/63kGU1xpg7
# neg: 0.15, neu: 0.728, pos: 0.121, compound: -0.1531,
# ⚠️ Pakenham/Cranbourne lines: Buses replace trains Caulfield - Westall tonight from 8:15pm due to maintenance and… https://t.co/EPAacVJvzf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# ⚠️ Frankston line: Buses replace trains Caulfield - Mordialloc tonight from 8:15pm due to maintenance works.
#
# Info:… https://t.co/Gkv5ZL3nZB
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# The Top 3 #DataVisualisation Courses at @udemy #matplotlib #tableau #dataviz #pythonprogramming… https://t.co/MArwd1ZwtC
# neg: 0.0, neu: 0.847, pos: 0.153, compound: 0.2023,
# No Route 82 trams from Stop 37 Union Rd &amp; Stop 32 Moonee Ponds. Passengers are advised to take diverting Route 57 t… https://t.co/mIFeru7VuV
# neg: 0.239, neu: 0.761, pos: 0.0, compound: -0.6808,
# Artificial Intelligence Trends To Watch In 2018 from @CBInsights: China is racing ahead in #AI… https://t.co/pyOmhCQvJt
# neg: 0.0, neu: 0.829, pos: 0.171, compound: 0.4767,
# 24 Uses of Statistical Modeling (Part II) https://t.co/gBOHSKpumg
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# “Even though this isn’t my country, this is where I’ve grown up. It would hurt so much to leave”
#
# https://t.co/tDffLf3vhs
# neg: 0.152, neu: 0.848, pos: 0.0, compound: -0.5267,
# ICOs delivered at least 3.5x more capital to blockchain startups than VC since 2017 https://t.co/Iz0O4XTdOJ
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @bestqualitycrab: Frances McDormand’s public call for celebrities with power to ask for an #inclusionrider on their movies is a stroke o…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @teacherACER: In today's infographic, educators share advice with their peers on the topic of relationships. https://t.co/Sv8CovtO2D #Wo…
# neg: 0.0, neu: 0.885, pos: 0.115, compound: 0.296,
# Decadence and depravity is engulfing Canberra. God help Malcolm Turnbull #auspol https://t.co/bpT2B031UM
# neg: 0.0, neu: 0.676, pos: 0.324, compound: 0.5859,
# https://t.co/vNWPaq8aFm
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 14 #Educational #apps to #teach kids #Coding:
# https://t.co/0tnBTZKWzk
# #edtech #edtechchat #Programming #teaching #aussieED #ozcsteachers
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# A guide to staying one step ahead of modern #email attackers
# https://t.co/7riaggxV34 #security #hacking #Hackers... https://t.co/ShiQ8ewbCL
# neg: 0.209, neu: 0.791, pos: 0.0, compound: -0.5719,
# A guide to staying one step ahead of modern #email attackers
# https://t.co/7riaggxV34 #security #hacking #Hackers… https://t.co/PlStTuH87C
# neg: 0.209, neu: 0.791, pos: 0.0, compound: -0.5719,
# Limited Route 57 Replacement Buses are operating from Stop 20 Melrose St and Stop 37 Union Rd. Replacement buses ar… https://t.co/6EtOHt5MHb
# neg: 0.259, neu: 0.741, pos: 0.0, compound: -0.6486,
# Archie Green is a new, all-day bar and eatery inspired by Melbourne life - delicious cocktails, great food, vibrant… https://t.co/orZpkGuBpy
# neg: 0.0, neu: 0.577, pos: 0.423, compound: 0.9001,
# Know the enemy before preparing #cyber defence: An in-depth look at #phishing
# https://t.co/4A1kxzDsni
# #hacking... https://t.co/z8Tn1rv3F8
# neg: 0.196, neu: 0.726, pos: 0.078, compound: -0.4767,
# Know the enemy before preparing #cyber defence: An in-depth look at #phishing
# https://t.co/4A1kxzDsni
# #hacking… https://t.co/6459cdu5rl
# neg: 0.196, neu: 0.726, pos: 0.078, compound: -0.4767,
# Learn the 5 reasons why #CorrelationdoesnotimplyCausation with this #freeebook https://t.co/4LQZqDwKGf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Quantum Computing and Deep Learning. How Soon? How Fast? https://t.co/C625nbqdbH
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Enterprise AI insights from the AI Europe event in London https://t.co/MkMGzmMUrE
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @CarlaHustedt: “AI in education is much more than technology. It is political.” @JoergDraeger at #KIES2018 on #EdTech and #ethics of #al…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# No time for trial by media as relaxed Cardinal saunters in to court https://t.co/w1J1DG8CmZ
# neg: 0.126, neu: 0.69, pos: 0.184, compound: 0.25,
# Scheduled a blog post to go out tomorrow morning. Feels like forever since I published on my blog!
# neg: 0.0, neu: 0.843, pos: 0.157, compound: 0.4199,
# .@wellcometrust and @UKRI_News launch reviews of policies that require funded papers to be made freely available
# https://t.co/x2gqSAXLbY
# neg: 0.0, neu: 0.847, pos: 0.153, compound: 0.4404,
# Sales Data Analysis using DataIku Studio https://t.co/BE67ud1ZRm
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @chaseTHEdonkey: The latest Travel Croatia like a local! https://t.co/HBa0r4faxx Thanks to @GGdaman49 @rome2rio @SecreTraveller_ #croati…
# neg: 0.0, neu: 0.695, pos: 0.305, compound: 0.69,
# Data Mining oppurtunity for Health Care providers https://t.co/GRgEUisOZF
# neg: 0.0, neu: 0.686, pos: 0.314, compound: 0.4939,
# 10 Blog From Rock-Star #DataScientists via @datasciencectrl https://t.co/VZByPFwEsf https://t.co/xPx2a8mc65
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Which Celebrity Movie Star Do You Look Like? https://t.co/xwueMaNkRY
# neg: 0.0, neu: 0.762, pos: 0.238, compound: 0.3612,
# Craigieburn line: Passengers connecting with @yarratrams Route 57 services are advised that service changes are in… https://t.co/IYRs9ZtWYi
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Update:
# Due to a truck bringing down powerlines on Racecourse Rd near CityLink:
# - Route 57 trams in both directions… https://t.co/skEa9vRyhb
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# This must’ve been so much fun to Photoshop. https://t.co/V72OOtVMjS
# neg: 0.0, neu: 0.691, pos: 0.309, compound: 0.5542,
# RT @nathanaelcooper: In a huge shock The Shape of Water has won the #Oscar for best film, pipping widely tipped Three Billboards.
# neg: 0.087, neu: 0.57, pos: 0.342, compound: 0.8225,
# The best picture goes to ... The Shape of Water #oscars https://t.co/wa7gexYOLj
# neg: 0.0, neu: 0.724, pos: 0.276, compound: 0.6369,
# Netflix's 'Icarus' wins the Oscar for Best Documentary Feature https://t.co/2z6zPUUQpC by @anthonyha
# neg: 0.0, neu: 0.559, pos: 0.441, compound: 0.836,
# RT @nathanaelcooper: Aussie Margot Robbie has missed out on the best actress #Oscar to Frances McDormand. More here: https://t.co/CpOv1gnikH
# neg: 0.094, neu: 0.726, pos: 0.179, compound: 0.4588,
# RT @nathanaelcooper: Garry Oldman wins best actor #Oscar for Darkest Hour.
# neg: 0.168, neu: 0.419, pos: 0.414, compound: 0.6908,
# Epson Rd Passengers: Can consider Bus 472 from Francis St. (Williamstown-Moonee Ponds) and change at Moonee Ponds j… https://t.co/kVLnzKAIdY
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Both might be good books: the genetic fallacy etc. But the conditional probability given the evidence is low, and I… https://t.co/1QMuMVQbuh
# neg: 0.112, neu: 0.805, pos: 0.083, compound: -0.1779,
# Ascot Vale Rd Passengers: Can consider Bus 404 (Footscray-Moonee Ponds) and change at Moonee Ponds junction to conn… https://t.co/VEtLbHPYEg
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Passengers are advised that this delay may take some time to clear
#
# Alternative transport: Passengers can consider… https://t.co/yZRpIvKijS
# neg: 0.124, neu: 0.754, pos: 0.122, compound: -0.0065,
# Have You Heard About Unsupervised Decision Trees https://t.co/89WhBtWHSG
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @DataScienceCtrl: Invitation to join Data Science Central
# https://t.co/2WSqR5Po14 https://t.co/0EwvstpZzY
# neg: 0.0, neu: 0.804, pos: 0.196, compound: 0.296,
# New Comprehensive Taxonomies on Mobile Security and Malware Analysis https://t.co/OwHBQSjQln
# neg: 0.0, neu: 0.645, pos: 0.355, compound: 0.5267,
# Due to a power fault on Racecourse Rd:
# - Route 57 trams in both directions are diverting via Mt Alexander Rd &amp; Asco… https://t.co/WgvnNIwELO
# neg: 0.114, neu: 0.886, pos: 0.0, compound: -0.4019,
# RT @KirkDBorne: 17 Sample Projects for #DataScientists to develop their skills: https://t.co/iCZLigHxA7 #abdsc #BigData #DataScience #Predi…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @philosophygeek: Proofs of the Pythagorean theorem are always magical - easily understood, but always a flash of mathematical brilliance…
# neg: 0.0, neu: 0.909, pos: 0.091, compound: 0.1779,
# RT @granvilleDSC: Checking out PySpark Cheat Sheet: Spark in Python on #DataScience Central: https://t.co/N3f8K2MWAE #DataScientist #BigDat…
# neg: 0.159, neu: 0.741, pos: 0.101, compound: -0.2732,
# RT @KirkDBorne: Unsupervised Decision Trees: https://t.co/fj1TqLaLR0 #abdsc #BigData #DataScience #MachineLearning #Algorithms https://t.co…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Ran across two books this evening that looked kinda interesting, but a little later crossed both off my list, one b… https://t.co/MfXg7k5ytX
# neg: 0.0, neu: 0.922, pos: 0.078, compound: 0.1787,
# RT @4orgexcellence: Great article! New Rules for Becoming a #DataScientist: https://t.co/aJtCgy6dTu         #BigData #DataScience #MachineL…
# neg: 0.0, neu: 0.732, pos: 0.268, compound: 0.6588,
# RT @Ronald_vanLoon: Fraud detection in retail with graph analysis
# by @Analyticbridge @irregularbi @jvilledieu |
#
# https://t.co/yGTWdZOlAP
#
# #…
# neg: 0.213, neu: 0.787, pos: 0.0, compound: -0.5859,
# RT @KirkDBorne: Great weekend readings in #DataScience and #MachineLearning at @analyticbridge https://t.co/ZVCUZ71j55 #abdsc #BigData #AI…
# neg: 0.0, neu: 0.773, pos: 0.227, compound: 0.6249,
# RT @KirkDBorne: Differences between #CognitiveComputing and #AI -- Moving From Hype to Deployment: https://t.co/4hB0mf8Yxh #abdsc #BigData…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @granvilleDSC: Checking out 23 types of regression on #DataScience Central: https://t.co/4lPJw2epK8 #DataScientist #BigData #IoT #Intern…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Do we want to live in an echo chamber, or do we want to be bombarded by negative, and sometimes hurtful content? https://t.co/wfWomox6Sf
# neg: 0.247, neu: 0.662, pos: 0.091, compound: -0.7579,
# RT @AcademicsSay: Me (before coffee): “Academia is a publishing-industrial complex fuelled by status cues and free labour to create termino…
# neg: 0.0, neu: 0.759, pos: 0.241, compound: 0.6597,
# How Digital is changing the workplace? https://t.co/YofgvlUybB
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Flop, fumble or fly - this year's Birdman Rally contenders are all brave in our eyes. See them at Moomba on 11 Marc… https://t.co/ac8DVfaSAq
# neg: 0.09, neu: 0.784, pos: 0.127, compound: 0.25,
# Feminism and film, it's a black and white issue at the Oscars, via @melly_singer  https://t.co/H1P4hecpMz
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Amazon analog of the crank list: People who bought this book also bought some wierd crap.
# neg: 0.142, neu: 0.765, pos: 0.093, compound: -0.2263,
# RT @ASUMathematics: At #Oscars, Rita Moreno shares quote by Frank Capra: There are three universal languages - music, #mathematics and film.
# neg: 0.0, neu: 0.896, pos: 0.104, compound: 0.296,
# A day after telling the world he's not sure if his partner is carrying his baby, Barnaby Joyce says personal questi… https://t.co/sgeelAY1qW
# neg: 0.089, neu: 0.911, pos: 0.0, compound: -0.2411,
# Quick Guide to R and Statistical Programming https://t.co/o3sBXyWUeV
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Ran across someone crankish and wanted to see how they scored.
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @nathanaelcooper: Josh Lawson has missed out on the #Oscar for live action short film. :(
# neg: 0.267, neu: 0.733, pos: 0.0, compound: -0.6249,
# Worth revisiting occasionally: seven signs of a crank
# https://t.co/GQQrCgM4zF
# neg: 0.0, neu: 0.787, pos: 0.213, compound: 0.2263,
# 3 Free Data Science eBooks to Add to Your Summer Reading List https://t.co/YgtqZdwFLc
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.5106,
# Simulating data to combat illegal fishing in R https://t.co/SIcN4Z2TJx
# neg: 0.5, neu: 0.5, pos: 0.0, compound: -0.7184,
# Congratulations! 🇦🇺️https://t.co/Z3HmRKJlBf https://t.co/0FkwWXS9ZE
# neg: 0.0, neu: 0.323, pos: 0.677, compound: 0.636,
# Tony Abbott says Malcolm Turnbull must answer for drop in polls #auspol https://t.co/abFrE7276z
# neg: 0.149, neu: 0.851, pos: 0.0, compound: -0.2732,
# RT @ProfPCDoherty: The "little mates" that we elected. Revealed: the extent of job-swapping between public servants and fossil fuel lobbyis…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Blockchain Basics https://t.co/KTVCDRNxhJ
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Read more https://t.co/Z3HmRKJlBf https://t.co/ErZDmW3TDz
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @drfeifei: Super important work! The development of Responsible #AI guidelines in companies and governments is just as important as the…
# neg: 0.0, neu: 0.627, pos: 0.373, compound: 0.8439,
# Unintended Consequences of the Wrong Measures https://t.co/4YVsssbDsT
# neg: 0.341, neu: 0.659, pos: 0.0, compound: -0.4767,
# Update: Route 78 trams to North Richmond have now resumed following the earlier disruption. Delays may still occur… https://t.co/vfsm4mRHdj
# neg: 0.122, neu: 0.878, pos: 0.0, compound: -0.3612,
# Holy shit! I discovered Trump’s hair in suburban Bellevue. https://t.co/h40fjATcCp
# neg: 0.327, neu: 0.673, pos: 0.0, compound: -0.5983,
# If Data is as Valuable as Gold, It�s Time to Polish Your Data Architecture https://t.co/avtcI1WaA5
# neg: 0.0, neu: 0.819, pos: 0.181, compound: 0.4767,
# RT @PRO_Vic: Packed platform @ Lilydale for #SuburbsofMelbourne Monday. This photo shows the first electric train at the Station. https://t…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# It took me WAY too long to realize that they switch out the chocolate bar during the diagram overlay part. This GIF… https://t.co/XEyGU8sf8K
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Natural Language Processing: Measuring Semantic Relatedness https://t.co/Dn2Jf2V0wx
# neg: 0.0, neu: 0.706, pos: 0.294, compound: 0.3612,
# See one of the funniest, most mesmerising illusionist couples right here in Melbourne: https://t.co/FqTOnCeIJK https://t.co/cCiLisHGr4
# neg: 0.0, neu: 0.795, pos: 0.205, compound: 0.5574,
# There are five Australians nominated for an #Oscar this year. Follow our blog to see how they fare  🎬✨ https://t.co/tVkHVT6b3p
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Update: Passengers may consider Bus 246 along Punt Rd to connect with Route 75 trams along Bridge Rd, and Route 70… https://t.co/qQbhtYyB3s
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @missrobyngrace: BREAKING: Berwick house where young girl was attacked by family pet subject to prior animal-safety complaints, says cou…
# neg: 0.241, neu: 0.759, pos: 0.0, compound: -0.6908,
# Cyclists 🚴‍♀️🚵‍♀️🚴‍♂️🚵‍♂️- Assist your fellow passengers by being aware of where you can travel on suburban trains… https://t.co/MGeK9AAZzc
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Route 78 trams to North Richmond are delayed due to an ill passenger in Church St.
# neg: 0.251, neu: 0.749, pos: 0.0, compound: -0.5719,
# George Pell's barrister has taken a swipe at Victoria Police, saying they presumed the Cardinal was guilty while in… https://t.co/PqcvFBmKeZ
# neg: 0.135, neu: 0.865, pos: 0.0, compound: -0.4215,
# Are you a current international student in Victoria who wants to share your journey and help the international... https://t.co/jBOl7IjI47
# neg: 0.0, neu: 0.766, pos: 0.234, compound: 0.5994,
# The new arms race in AI: China is making big investments in artificial intelligence, looking for military advantage… https://t.co/rnR0FAY3LS
# neg: 0.0, neu: 0.853, pos: 0.147, compound: 0.4767,
# RT @acooperjourno: Young ringleader to spend three years in jail over armed robberies, writes @TammyMills1 -https://t.co/sTalOAf17h
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Check out my new #freebook on Amazon! Truth, Lies and #Statistics  https://t.co/GHdTLnDFn3 https://t.co/FwsPAfsBQL
# neg: 0.164, neu: 0.585, pos: 0.251, compound: 0.126,
# Join us as we bring you all the #Oscars action from our live blog. Follow our entertainment editor-at-large… https://t.co/pUGBBw2ARP
# neg: 0.0, neu: 0.773, pos: 0.227, compound: 0.6124,
# 17 Great Blogs Posted in the last 12 Months https://t.co/OqtyPSiwyy
# neg: 0.0, neu: 0.687, pos: 0.313, compound: 0.6249,
# Data Science Simplified Part 2: Key Concepts of Statistical Learning https://t.co/rtGNUSds4n
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Reopened! The Prince Alfred is back in action - https://t.co/sZjHykw6zQ https://t.co/JomlXFEYiR
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# What is the right mix of competences for Data Scientists? https://t.co/0iU9VSiesK
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Sunbury line: Minor delays due to an overhead power fault between Sunshine and Tottenham.
# Please listen for announc… https://t.co/H6PKFYxvPt
# neg: 0.112, neu: 0.661, pos: 0.227, compound: 0.4215,
# RT @nathanaelcooper: So @TheRitaMoreno is wearing the same frock she wore to the Oscars in 1962 and I am DED. Cremated. Buried. RIP me. htt…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Follow our fashion columnist @melly_singer for a look at all the fabulous frocks from Hollywood's night of nights 👗… https://t.co/QtmAOT2XoC
# neg: 0.0, neu: 0.841, pos: 0.159, compound: 0.5267,
# The ROI of Machine Learning in Business - Infographics https://t.co/bDYxvAJV4c
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Analyzing The Hype Around Big Data - A Balanced View https://t.co/b7gcPiTDin
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @ndiakopoulos: NIST is running a media forensics challenge this year: https://t.co/X0nkdtTdYG
# neg: 0.0, neu: 0.885, pos: 0.115, compound: 0.0772,
# RT @LaFamiliaFilm: How well does Mike Nichols's 'The Graduate' hold up today? @OrrChris, @megangarber, @AdrienneLaF, and @conor64 discuss t…
# neg: 0.0, neu: 0.896, pos: 0.104, compound: 0.2732,
# State-of-the-Art Machine Learning Automation with HDT https://t.co/obDLfZ6dui
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Book: Machine Learning with R - Second Edition https://t.co/nkP69gk4dy
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 76% of audited Caltex franchises found to be underpaying workers https://t.co/McNdaMuHz9 https://t.co/DIO2GxvLr9
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Oh YES YES YES! https://t.co/j48bwHrVqP
# neg: 0.0, neu: 0.159, pos: 0.841, compound: 0.8908,
# Facebook’s next money-maker: Messenger Broadcasts https://t.co/4q5easUKIQ
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Aussie Farmers Direct has gone into administration and will close immediately, leaving more than 100 franchisees an… https://t.co/0378kM00I6
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Thank you @PECOconnect for all your hard work to restore power to the mainline.
# neg: 0.082, neu: 0.643, pos: 0.275, compound: 0.5106,
# Explainable Artificial Intelligence (XAI) https://t.co/qNqFKnNLUc
# neg: 0.0, neu: 0.563, pos: 0.437, compound: 0.4767,
# RT @oplifesaver: Listening to loud music or talking on the phone could prevent you from hearing a train—and having your attention elsewhere…
# neg: 0.0, neu: 0.948, pos: 0.052, compound: 0.0258,
# RT @olinational: Railway tracks are not a safe shortcut. Practice #railsafety. https://t.co/e9RmCc2iiI
# neg: 0.194, neu: 0.806, pos: 0.0, compound: -0.3412,
# Text Normalization with Spark � Part 2 https://t.co/4vLbJgbULZ
# neg: 0.0, neu: 0.725, pos: 0.275, compound: 0.2263,
# .@EMMAREES on a challenging study that leads to flashbacks of Foucault and ‘Xena: Warrior Princess’
# https://t.co/scVnl9niiq
# neg: 0.0, neu: 0.897, pos: 0.103, compound: 0.1531,
# Learn to be a #DataScience Ninja - The Easy Way #artificialintelligence #statistics #rprogramming… https://t.co/kZ69tOcIVG
# neg: 0.0, neu: 0.791, pos: 0.209, compound: 0.4404,
# 2016: the Year of Mobile Health https://t.co/ltgVA6FH8z
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Test the outer limits of your comfort zone at Rest Area, a makeshift bedroom in the back of a truck that invites yo… https://t.co/41CTqiPjxT
# neg: 0.0, neu: 0.894, pos: 0.106, compound: 0.3612,
# RT @DBaker007: Must Know Tips/Tricks in Deep #NeuralNetworks | @DataScienceCtrl https://t.co/cq63yQTXVt #CNNs #AI #ArtificialIntelligence #…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @granvilleDSC: Checking out Data Science in Python: Pandas Cheat Sheet on #DataScience Central: https://t.co/CyXHGaemOk #DataScientist #…
# neg: 0.158, neu: 0.842, pos: 0.0, compound: -0.4588,
# RT @HomesAtMetacoda: 😂🤓 #programming #developer #programminglanguage RT @datasciencectrl: Which Programming Language to Choose?
# https://t.c…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @KirkDBorne: 5 Pro-Tips For #DataScientists To Write Good Code: https://t.co/UqGK0dAOO1 #abdsc #BigData #DataScience #Coding
#
# (graphic b…
# neg: 0.0, neu: 0.838, pos: 0.162, compound: 0.4404,
# RT @KirkDBorne: 40 Techniques Used by #DataScientists, with links to articles for every one: https://t.co/hzZrSGw1F2 #abdsc #BigData #DataS…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @guy_inbar: #Melbourne - Last week found a Holden remote on the #Alamein line heading into the city. If you lost it then message me for…
# neg: 0.091, neu: 0.909, pos: 0.0, compound: -0.3182,
# “While the entrée in Canberra was a glorification of the past and of doors opening, the main course was about the f… https://t.co/PxLDBPlsJd
# neg: 0.0, neu: 0.875, pos: 0.125, compound: 0.4588,
# Career Alert, March 2: https://t.co/yg9U6wM8P5
# neg: 0.0, neu: 0.645, pos: 0.355, compound: 0.296,
# In 2017, #emergingmarkets &amp; #developingeconomies ran a deficit of 4% of GDP on average, the biggest since the globa… https://t.co/XElLKyrI8J
# neg: 0.13, neu: 0.87, pos: 0.0, compound: -0.4019,
# Great Sunday Reading: https://t.co/DFiMKVwi5N
# neg: 0.0, neu: 0.423, pos: 0.577, compound: 0.6249,
# Introduction to Blockchains &amp; What It Means to Big Data https://t.co/JK2LnyvKex
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Cardinal George Pell and his legal team have arrived at a Melbourne court to fight historical sexual offence charge… https://t.co/aVpavfAlSr
# neg: 0.215, neu: 0.717, pos: 0.067, compound: -0.5106,
# RT @jackmjenkins: “Bless your heart,” — The entire Southeast https://t.co/AEv6AQ8HVN
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Frankston line: Minor delays due to an equipment fault between Glenhuntly and Caulfield.
# Please listen for announce… https://t.co/tSz2LkelQ5
# neg: 0.129, neu: 0.762, pos: 0.11, compound: -0.1027,
# Building a Data Quality Strategy https://t.co/91QbB0AIom
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# BREAKING Cardinal George Pell mobbed by enormous international media pack as he arrives at a Melbourne court to sta… https://t.co/MFl0p7feXc
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Check out the most popular #datascience #courses at @Udemy https://t.co/XeEVinmPfu #Python #ArtificialIntelligence… https://t.co/DkRISxANaI
# neg: 0.0, neu: 0.795, pos: 0.205, compound: 0.4754,
# BREAKING Cardinal George Pell has arrived at court to fight charges of historical sexual offences
# neg: 0.372, neu: 0.628, pos: 0.0, compound: -0.7269,
# On "toy" models of social phenomena: "The rise and refinement of artificial societies is not going to be a magic mi… https://t.co/iqMvnu31Rm
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Australia’s opposition has pledged to reinstate the country’s demand-driven higher education system and to “restore… https://t.co/qOVO1ui1NN
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Update: Route 86 trams towards Waterfront City Docklands have now resumed following the earlier disruption. Delays… https://t.co/hwzYuJi20d
# neg: 0.254, neu: 0.746, pos: 0.0, compound: -0.6249,
# When #MachineLearning Started To Sense The World by @GilPress via @Forbes https://t.co/IpKYuxYQvz https://t.co/NfIH3se6JC
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Read this thread by @JoeWasserman before getting too excited about the recent toy model of luck vs talent in determ… https://t.co/2fk2OA0zKW
# neg: 0.0, neu: 0.687, pos: 0.313, compound: 0.802,
# Take some time out after work and visit Arts House for Let's Go Up Here, a landscape painting workshop with a twist… https://t.co/ZQE5BdW4qT
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 33 unusual problems that can be solved with data science https://t.co/HsMA3I4pqU
# neg: 0.196, neu: 0.652, pos: 0.152, compound: -0.1531,
# Agreed. Simulation models are useful for building intuition about what could be true, but do not on their own show… https://t.co/DND2TbNpXK
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.5267,
# Craigieburn/Sunbury/Upfield lines: Minor delays due to an ill passenger requiring medical assistance at Parliament.… https://t.co/huNojZLGai
# neg: 0.167, neu: 0.833, pos: 0.0, compound: -0.4215,
# Greens want $100 million pumped into video game development https://t.co/zGh1GP25Fg
# neg: 0.0, neu: 0.874, pos: 0.126, compound: 0.0772,
# Route 86 trams towards Waterfront City Docklands are delayed due to an emergency services request in High St.
# neg: 0.321, neu: 0.679, pos: 0.0, compound: -0.7269,
# RT @JoeWasserman: @stevenstrogatz @mjmauboussin @duncanjwatts @barnabymarsh @JaniceKaplan2 @sbkaufman Thank you for tempering claims by wri…
# neg: 0.0, neu: 0.848, pos: 0.152, compound: 0.3612,
# How 4,000 Physicists Gave a Vegas Casino its Worst Week Ever https://t.co/eCHEN4PSxT (ht @PhysicsCentral)
# neg: 0.255, neu: 0.745, pos: 0.0, compound: -0.6249,
# RT @PhysicsCentral: In April 1986, Las Vegas' MGM Grand hotel &amp; casino hosted 4,000 physicists for a conference...and had the worst financi…
# neg: 0.157, neu: 0.728, pos: 0.115, compound: -0.2732,
# Absolutely! Everyone, also take a look at this very nice piece by @sbkaufman about the fascinating new study on luc… https://t.co/BYrCBQ9pDm
# neg: 0.0, neu: 0.723, pos: 0.277, compound: 0.7836,
# Data Cleaning and Wrangling With R https://t.co/1foG7QpU7C
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# A toy model explores the role of luck vs. talent in determining success and failure (ht Bob Frank): original paper… https://t.co/8YJyzrXNyp
# neg: 0.11, neu: 0.498, pos: 0.392, compound: 0.8176,
# What doing #statistics by hand feels like. #DataScience #phdchat https://t.co/Gbgl74qt9W
# neg: 0.0, neu: 0.584, pos: 0.416, compound: 0.6908,
# Check out these 3 Free #DataScience #eBooks! #ml #datamining https://t.co/xTACWozvNq https://t.co/sda0YzFfv8
# neg: 0.0, neu: 0.715, pos: 0.285, compound: 0.5562,
# Cranbourne/Pakenham lines: Minor delays after earlier faulty equipment near Berwick and ill passengers at South Yar… https://t.co/7vIOucmwIR
# neg: 0.254, neu: 0.746, pos: 0.0, compound: -0.6249,
# .@Shaquemgriffin is a beast at the #NFLCombine. Talk about an outlier at his position!
#
# He'll no doubt be making us… https://t.co/u2WueaFRsH
# neg: 0.217, neu: 0.783, pos: 0.0, compound: -0.6114,
# Retweeting these for all of my #crowtalkhour friends. https://t.co/OrO5iyt9sq
# neg: 0.0, neu: 0.721, pos: 0.279, compound: 0.4767,
# Retweeting for #crowtalkhour.
#
# *Not really a fakie. The crow is flying up to land, not falling backward. https://t.co/jWYh2PEY2B
# neg: 0.0, neu: 0.917, pos: 0.083, compound: 0.1139,
# RT @MikeQuindazzi: In the #USA, people check their #smartphones a combined 8 billion times per day! @ReportLinker #digital #iot #bigdata #e…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Join leading social entrepreneur, influencer, and author, Jan Owens AM as she unpacks current issues and discusses… https://t.co/5zIa25TXzD
# neg: 0.0, neu: 0.885, pos: 0.115, compound: 0.296,
# 100+ Commonly Asked Data Science Interview Questions https://t.co/pF5CA1pPfE
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Daca dilemma: US universities torn between Dreamers and reality
# https://t.co/tDffLf3vhs
# neg: 0.316, neu: 0.684, pos: 0.0, compound: -0.4019,
# "This year, it's likely #Blockchain will quickly evolve from exciting buzzword to concrete tool - so why should... https://t.co/wD8rs1AxLz
# neg: 0.0, neu: 0.842, pos: 0.158, compound: 0.4939,
# How Python &amp; Tableau made an easy Data Analysis of Padma Shri Awards https://t.co/l9afYX8S6N
# neg: 0.0, neu: 0.67, pos: 0.33, compound: 0.7096,
# "This year, it's likely #Blockchain will quickly evolve from exciting buzzword to concrete tool - so why should you… https://t.co/z6yOZc6idC
# neg: 0.0, neu: 0.849, pos: 0.151, compound: 0.4939,
# Looks like there's a new competitor for Dask on the scene: Pandas on Ray.
#
# Early tests show that Pandas on Ray outp… https://t.co/wXTsjtBSVM
# neg: 0.0, neu: 0.894, pos: 0.106, compound: 0.3612,
# Top Hadoop Interview Questions &amp; Answers https://t.co/oey9IWhtr4
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.2023,
# Craigieburn line: Minor delays after an earlier faulty train at Essendon.
# Please listen for announcements as some s… https://t.co/tuQIFgSgIO
# neg: 0.106, neu: 0.787, pos: 0.106, compound: 0.0,
# Marmalade Launches Marmalade Club https://t.co/2Jp1Qo7br0 https://t.co/QWbpUGFp3d
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Are you on Pinterest and would like to contribute to my resources for #datascientists group board? Here's the link https://t.co/CefjFF3oOC
# neg: 0.0, neu: 0.884, pos: 0.116, compound: 0.3612,
# 40 Interview Questions asked at Startups in Machine Learning / Data Science https://t.co/0XkntlfLAR
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Pakenham line: Major citybound delays between Pakenham and Dandenong due to faulty equipment near Berwick.
# Listen… https://t.co/zpCCaZq74G
# neg: 0.126, neu: 0.874, pos: 0.0, compound: -0.3182,
# Here are the main #InsurTech cities by number of startups, in EU: London &gt; Paris &gt; Madrid &gt; Berlin. #FinTech #AI… https://t.co/hnchPdvXHP
# neg: 0.0, neu: 0.942, pos: 0.058, compound: 0.0772,
# Excellent post from @sbmeunier ! https://t.co/tfejg9uSwT
# neg: 0.0, neu: 0.501, pos: 0.499, compound: 0.6114,
# Why rising mortgage rates could have a 'catastrophic' impact on all of us https://t.co/ZtCA6pAeWo
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @futurism: “There's no logic in wrapping something as fleeting as food in something as indestructible as plastic.” https://t.co/HhGsiOSF…
# neg: 0.106, neu: 0.817, pos: 0.077, compound: -0.1531,
# UPDATE: Neighbour tells of giant dog "going berserk" in attack on young girl that left her with horrific injuries  https://t.co/k2bj7p9DM2
# neg: 0.294, neu: 0.706, pos: 0.0, compound: -0.8176,
# Prepping for Strata San Jose this week and just took a look at my Strata keynote slides from 2011.
#
# We've come a long, long way.
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# K2 Acquires Rockhill Insurance Group’s GL &amp; Gas &amp; Propane Distribution Businesses https://t.co/mo1dEJJVsj https://t.co/2E6KengiDS
# neg: 0.0, neu: 0.811, pos: 0.189, compound: 0.4648,
# Book: Text Analytics with Python https://t.co/jXTrHe3UQV
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Australia’s entire system of “yellow-lid bin” kerbside recycling at risk from China’s clampdown, governments told d… https://t.co/2bB2cyWtDZ
# neg: 0.116, neu: 0.884, pos: 0.0, compound: -0.2732,
# RT @goodfellow_ian: Adversarial examples for humans in IEEE Spectrum: https://t.co/4bUItJbQEk
# neg: 0.217, neu: 0.783, pos: 0.0, compound: -0.3612,
# 5 Ways Businesses Can Cultivate a Data-Driven Culture https://t.co/tD26RoVM5z
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Group of Eight chair aims to ‘raise quality’ of debate on higher education in Australia
# https://t.co/3umJw3yl5h
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# How a US-led trade war could wipe out millions of jobs https://t.co/7l6fwILT3Z
# neg: 0.281, neu: 0.719, pos: 0.0, compound: -0.5994,
# Monopoly or Underdog, Whats your flavor for soccer? https://t.co/o9hqtgYImt
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# What is Return Period? https://t.co/x5bxgO9ecX
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Screams heard as young girl thrown 'like a rag doll' in dog attack https://t.co/mDZIILsZ1j
# neg: 0.298, neu: 0.562, pos: 0.14, compound: -0.4215,
# Nippon Life to Acquire MassMutual Life https://t.co/QFkoRAJfye https://t.co/TQRO2FUlwf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @depsy_org: The Depsy project is officially concluded. Website will stay up, but maintenance ending. Thanks so much to the NSF for fundi…
# neg: 0.0, neu: 0.851, pos: 0.149, compound: 0.5927,
# One of the main challenges for #AI remains unsupervised learning, at which humans are much better than machines. Yo… https://t.co/QLw0wyG0pG
# neg: 0.0, neu: 0.811, pos: 0.189, compound: 0.4939,
# Also in Reinsurtech ! https://t.co/a0ZvQLnj5P
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Notes from Shenzhen -- the next Greater Bay Area https://t.co/zeKZElkpON by @rezendi
# neg: 0.0, neu: 0.815, pos: 0.185, compound: 0.3612,
# Check out this new #OnlineCourse: Data - Getting Yourself Organised with #Excel https://t.co/ENoZTZLUkt https://t.co/S2WX2VdmKu
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Some Thoughts on Mid-Career Switching Into Data Science https://t.co/jSPSlbp4Eq
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Pakenham line: Minor delays citybound Pakenham - Dandenong due to faulty equipment near Berwick. Listen for announc… https://t.co/bbkET2Vuly
# neg: 0.126, neu: 0.874, pos: 0.0, compound: -0.3182,
# Canadian academics celebrate major increase in basic research funding, but pledges fall short of recommendations in… https://t.co/EY1rpdFTmS
# neg: 0.0, neu: 0.789, pos: 0.211, compound: 0.4588,
# 6 Ways To Make #SmartCities Future-Proof #Cybersecurity Cities by @GilPress via @forbes https://t.co/c3n1qEcPuz https://t.co/2YwZUMdZu6
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# COMMENT It's time for Vikki Campion's friends to stage an intervention https://t.co/hetYD920i0
# neg: 0.0, neu: 0.78, pos: 0.22, compound: 0.4767,
# Best practices of orchestrating Python and R code in ML projects https://t.co/6SDNi2LPIG
# neg: 0.0, neu: 0.704, pos: 0.296, compound: 0.6369,
# ICOs delivered at least 3.5x more capital to blockchain startups than VC since 2017 https://t.co/tf8LFMY3Al by @jason_rowley
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# The sun is the most plentiful source of renewable energy we have -- and the race is on to harness its power. https://t.co/qWt0LWwXbd
# neg: 0.0, neu: 0.913, pos: 0.087, compound: 0.2732,
# Check out my new #freebook on Amazon! Truth, Lies and #Statistics  https://t.co/GHdTLnDFn3 https://t.co/iVqNkPYa0X
# neg: 0.164, neu: 0.585, pos: 0.251, compound: 0.126,
# In case you missed it, here's my latest gems post: https://t.co/j9PQf8wy3m
# neg: 0.18, neu: 0.82, pos: 0.0, compound: -0.296,
# “The most difficult part of the doctoral degree is coping with the guilt of not being around for my loved ones as m… https://t.co/WpPQIBW4xF
# neg: 0.164, neu: 0.705, pos: 0.131, compound: 0.0018,
# Top IT Training Trends to Watch Out For in 2017 https://t.co/48tTsMypPE
# neg: 0.0, neu: 0.847, pos: 0.153, compound: 0.2023,
# #Fintech #Insurtech #AssetTech #API = learn about @Particeep API platform in 2 minutes https://t.co/LiCJBp7piN https://t.co/HShCFNYfXq
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# .@YouTube removes ads from InfoWars’ Alex Jones channel but says it has no plans to delete it https://t.co/Hko0wXZFo4
# neg: 0.141, neu: 0.859, pos: 0.0, compound: -0.4215,
# And a few more with some mathematical words... https://t.co/TI0n77b9nt   #mathschat https://t.co/jv53G6Z0SP
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Weekly Digest, March 5 https://t.co/ylqcc4noLw
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Interactive trees for exploring (mathematical) vocabulary with students. https://t.co/lKg8seJNLi
#
# Last time I taugh… https://t.co/h5KSG7pooC
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Sth Morang line: Minor delays Sth Morang - Clifton Hill after late running engineering works overnight.  Listen for… https://t.co/J2qofEFd4y
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Sunbury line: Minor delays citybound and major delays outbound Sunbury - Watergardens due to late running engineeri… https://t.co/LqAuIx1pew
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Snapchat is stuck in the uncanny valley of AR glasses https://t.co/j5s1aheo00 by @joshconstine
# neg: 0.143, neu: 0.857, pos: 0.0, compound: -0.25,
# Exposed nerve endings: lab bench discoveries made during the 1800s were felt in the playhouse, says @matthewrbroome
# https://t.co/AZlkKUcpd5
# neg: 0.071, neu: 0.929, pos: 0.0, compound: -0.0772,
# RT @beeonaposy: "[if you experience miscarriage] there is no power on earth that can unsubscribe you from the ad tracking that pregnant wom…
# neg: 0.091, neu: 0.909, pos: 0.0, compound: -0.296,
# Under the Hood with Reinforcement Learning � Understanding Basic RL Models https://t.co/EAB8Vld4DN
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 10 Required Non-technical Skills for a Data Scientist https://t.co/XVaULIYRcf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# How Big Data is Changing the World of Soccer https://t.co/SLmHk0dLQN
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Ripple (XRP) – There’s Another Clear Reason It Look Unstoppable https://t.co/BiA0jE3XVB #xrp
# neg: 0.134, neu: 0.672, pos: 0.194, compound: 0.2023,
# #Blockchain Daily is out now!
#
# A daily round-up of blockchain &amp; #DLT stories from across social media
#
# https://t.co/r8Y1rehpSo
#
# #FinTech
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# How #AutonomousVehicles will oblige carmakers to rethink their business model, insurers will have to design new mob… https://t.co/QnX8ugLpzM
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Top 10 AI events of 2016 https://t.co/fyGXqPRh8P
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.2023,
# WTF is CFIUS? https://t.co/NNU5BUk43Z by @DannyCrichton
# neg: 0.476, neu: 0.524, pos: 0.0, compound: -0.6739,
# US universities walk a fine line as the Daca deadline approaches – wanting to support ‘Dreamer’ students, but not w… https://t.co/3BiJD3CquK
# neg: 0.0, neu: 0.84, pos: 0.16, compound: 0.3071,
# RT @IanDunt: Every sentence of the Observer editorial on Theresa May’s speech is spot on https://t.co/Xr7fp4aikZ
# neg: 0.0, neu: 0.92, pos: 0.08, compound: 0.0772,
# Weekly Digest, March 5: https://t.co/FZiaY90PTF
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Healthcare Investments and Exits 2018 https://t.co/UwMCeKLnYG https://t.co/pwlpiUG8iC
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# The Top 3 #DataVisualisation Courses at @udemy #matplotlib #tableau #dataviz #pythonprogramming… https://t.co/B4cbwh5Z2n
# neg: 0.0, neu: 0.847, pos: 0.153, compound: 0.2023,
# YouTube removes ads from InfoWars' Alex Jones channel but says it has no plans to delete it https://t.co/aQrDMoSUJH by @ingridlunden
# neg: 0.128, neu: 0.872, pos: 0.0, compound: -0.4215,
# Natural Language Understanding � Application Notes with Context Discriminant https://t.co/j06qCQDX5P
# neg: 0.0, neu: 0.762, pos: 0.238, compound: 0.3612,
# RT @sonnyrollins: https://t.co/ERfedPrCCY
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Book: Python For Dummies https://t.co/WMUTFxJhGM
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @omidmnz: @stevenstrogatz And of course, the three Joel Tropp lectures on the topic: User-Friendly Tools for Random Matrices
# https://t.c…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 28 Industries Other Than Auto That Driverless Cars Could Turn Upside Down https://t.co/C71i7cmqOV via @cbinsights
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Tina Sharkey of Brandless has something to sell you (300 things, actually) https://t.co/rKqsWyggxn
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# .@ScienceEurope chief hopes for experiments with grant lottery system and even a basic income for researchers
# https://t.co/xjWRBEvyF6
# neg: 0.0, neu: 0.725, pos: 0.275, compound: 0.6486,
# RT @Phil_Baty: Academy Awards nominations 2018: Where did the Oscar nominees go to university? Starring @nyuniversity @Yale @EmersonCollege…
# neg: 0.0, neu: 0.85, pos: 0.15, compound: 0.4588,
# A to Z of Analytics https://t.co/T2YLKFinwL
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Review: Google Clips https://t.co/c7qws7uAsj https://t.co/PAjYxWLh08
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# I built a Chatbot in 2 hours and this is what I learned https://t.co/FCUtz3Ua47
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Catching up on Big Data &amp; Healthcare https://t.co/BR7GUQzLvc
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @george_berry: Representing #dota2 heroes in two dimensions
# - @opendota for match data
# - @PyTorch for neural network embedding
# - ggplot2…
# neg: 0.0, neu: 0.837, pos: 0.163, compound: 0.5106,
# Inflicting bright wounds: a guide for depressed scholars
# https://t.co/6H95OgOMfZ
# neg: 0.27, neu: 0.492, pos: 0.238, compound: -0.1027,
# RT @Livingstone_S: Really? The biggest obstacles to kids achieving at school are the drill-and-skill curriculum, overstretched teachers, un…
# neg: 0.144, neu: 0.856, pos: 0.0, compound: -0.4336,
# Recommendation System Algorithms https://t.co/yMkVpUqeeW
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Recommenders: Packaged Solutions or Home Grown https://t.co/ckTP6R16x3
# neg: 0.0, neu: 0.779, pos: 0.221, compound: 0.1779,
# Visit the @Worldbank Climate Change Knowledge Portal for info, data &amp; reports about #climatechange around the world… https://t.co/pkN4N4hUfG
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @danoprisa: Awesome - short and concise! For a deeper dive, the blog from Terrence https://t.co/TtHUcn71jR https://t.co/1MbdGtUSA8
# neg: 0.0, neu: 0.761, pos: 0.239, compound: 0.6588,
# #Onlinecourse: #datacleaning for #analysts and #researchers https://t.co/7ijTRVcWDj #excel https://t.co/1nAUYQ4c5r
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# .@KeithKahnHarris on a pan-European event that is as much about competition and national identities as it is cooper… https://t.co/6ZClQrhBbr
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Just arrived in Hanoi. Looking forward to meeting and chatting with Ss and Ts at @UNIS_Hanoi over the next two days… https://t.co/Ycq6VRm07W
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Higher Ed?�?will it adapt? https://t.co/W60RiialXj
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Can’t wait to look at this video series by @BenHambrecht (who authored the latest @3Blue1Brown video) Visual Algebra https://t.co/e2A1E8aqF3
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Reviving the Art of Storytelling (as opposed to mere lecturing in the classroom), by @BenHambrecht - https://t.co/MOyhxcniNb
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# The final hurdle to gaining a PhD, is labour-intensive, not conducted to any national standard and is dreaded by st… https://t.co/udpLyFgDlr
# neg: 0.151, neu: 0.735, pos: 0.114, compound: -0.2263,
# RT @_tim_hutton_: @3Blue1Brown @BenHambrecht Is there a similar visual insight into why
#
# 2/1 * 2/3 * 4/3 * 4/5 * 6/5 * 6/7 * 8/7 * ... = π…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @BenHambrecht: @_tim_hutton_ @3Blue1Brown There is, by the same author: https://t.co/5CqeS7x4dJ
# See also Don Knuth‘s talk „Why pi“
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# It’s wonderful. You guys make a great team! https://t.co/6DAtfPNoys
# neg: 0.0, neu: 0.426, pos: 0.574, compound: 0.8439,
# Peter Thiel's Founders Fund made a bet on bitcoin that's now worth hundreds of millions of dollars… https://t.co/ZCCOiAgp7B
# neg: 0.0, neu: 0.894, pos: 0.106, compound: 0.2263,
# A Great Year for Digital Resolutions - Insurance Thought Leadership https://t.co/a3mOlIIi5M #insurtech
# neg: 0.0, neu: 0.687, pos: 0.313, compound: 0.6249,
# #DigitalInsurance Daily is out!
#
# A round-up of #Digital #Insurance &amp; #iInsurTech from across social media
#
# https://t.co/0e0WY5XaIZ
#
# #Fintech
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @McK_Utah: The “PostDoc Salaries” site is up! Like https://t.co/F8MZYArcZ2 but for PDs 🤗 Input your current or past salary/benefits, see…
# neg: 0.0, neu: 0.903, pos: 0.097, compound: 0.2598,
# Roger Bannister, the first man to run a mile in under four minutes, has died aged 88 https://t.co/p131lFvwt3
# neg: 0.184, neu: 0.816, pos: 0.0, compound: -0.5574,
# Random matrices - a high level, fast, readable intro to the main ideas [pdf] https://t.co/flmpM6PowT
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# For academics and students alike, pressure to perform coupled with a lack of institutional support can severely aff… https://t.co/VrFa7HA7S4
# neg: 0.31, neu: 0.579, pos: 0.112, compound: -0.5859,
# Must read for #startup: how the #GDPR regulation will impact the way you develop. #UX #InsurTech https://t.co/9xVcmVa5xM
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# A Majority of #DataScientists Lack Competency in Advanced #MachineLearning Areas and Techniques… https://t.co/ungWmotvRw
# neg: 0.161, neu: 0.699, pos: 0.14, compound: -0.0772,
# Discover the story of your data in minutes: Find out more: https://t.co/zoEHpe0CZR #statisticalanalysis https://t.co/pF38zqgRfF
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# This video by @3Blue1Brown is fantastic! So many fun ideas, and so clever and clearly explained and visualized.  https://t.co/e9UzCGLlDe
# neg: 0.0, neu: 0.512, pos: 0.488, compound: 0.936,
# RT @guygavrielkay: OK, pause jokes and politics for a sec. Here's a Breaking News thing. Short version: The really impressive team that did…
# neg: 0.0, neu: 0.679, pos: 0.321, compound: 0.8189,
# 5 #BusinessIntelligence Myths, Debunked #BI via @insidebigdata https://t.co/tkW60frffr
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Check out my new #freebook on Amazon! Truth, Lies and #Statistics  https://t.co/GHdTLnDFn3 https://t.co/WslIcWR4dE
# neg: 0.164, neu: 0.585, pos: 0.251, compound: 0.126,
# “When studying at this level, sacrifices in your spare time are inevitable”
# #PhDlife
#
# https://t.co/j3s5PAet3f
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# UK to use #machinelearning to boost #airportscreening security via @cbronline https://t.co/whOMfyG01V
# neg: 0.0, neu: 0.638, pos: 0.362, compound: 0.6249,
# How to Analyze Big Data with Excel https://t.co/Oh8NG2iBr9
# neg: 0.0, neu: 0.7, pos: 0.3, compound: 0.4588,
# Free Book: SQL Essentials https://t.co/wzLDzYuE75
# neg: 0.0, neu: 0.548, pos: 0.452, compound: 0.5106,
# Alternative credentials and providers #highered https://t.co/jBCRPIHW6o
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Quarter Million Dollars Already Raised in Bitcoin Cash 48 Hour Challenge - Bitcoin News https://t.co/pRkZGI5kWY By @CryptoKelso #bitcoin
# neg: 0.0, neu: 0.925, pos: 0.075, compound: 0.0772,
# #Crypto Daily is out!
#
# A daily round-up of top #cryptocurrency stories from social media by @rickhuckstep
#
# https://t.co/t9oGu7ThKb
#
# #fintech
# ...
# RT @seanmcarroll: @stevenstrogatz This is not really Juan Maldacena! cc: @AstroKatie @mcnees @aatishb @michael_nielsen @LalaTellsAStory
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Technology has to follow your data strategy https://t.co/Ccd96nUIml
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Gary Ablett is back at Geelong and he's almost as happy about it as @GeelongCats  fans https://t.co/5zQOGr06mW
# neg: 0.0, neu: 0.824, pos: 0.176, compound: 0.5302,
# Instagram code reveals unreleased voice and video calling https://t.co/EaAunqYkte
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 16 Rules that Helped C-Suite Trust Analytics https://t.co/tJW0PvFSio
# neg: 0.0, neu: 0.68, pos: 0.32, compound: 0.5106,
# Data Devils Snapping At Your Heals https://t.co/J14ASlk2Vu
# neg: 0.381, neu: 0.619, pos: 0.0, compound: -0.5719,
# 10 Blogs from Rock-star Data Scientists https://t.co/8gQTjqOLzL
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Live entertainment, giveaways and costume prizes! Head to Fed Square today to check out Avengers S.T.A.T.I.O.N and… https://t.co/AL9uaDROYa
# neg: 0.0, neu: 0.724, pos: 0.276, compound: 0.7263,
# Franchising under fire after RFG announcement: 'They live like kings, we work like slaves' https://t.co/2pnDdftW1X
# neg: 0.124, neu: 0.619, pos: 0.258, compound: 0.3818,
# Introduction to #PythonEnsembles #pythonprogramming via @kdnuggets https://t.co/VGIvuEl9BD https://t.co/1jUSRAxh52
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Collins St trams have resumed along normal lines after an earlier disruption. Delays may occur as we restore normal frequency.
# neg: 0.11, neu: 0.793, pos: 0.097, compound: -0.0772,
# RT @lucaswiman: @seanjtaylor “Type I and type II opportunities to do better next time.”
# neg: 0.0, neu: 0.667, pos: 0.333, compound: 0.6705,
# 3 Great #DataScience #Books for Aspiring #DataScientists https://t.co/UYtDitqnZd https://t.co/4EhHx60FV9
# neg: 0.0, neu: 0.631, pos: 0.369, compound: 0.6249,
# .@VicMarket Lantern Festival is on this weekend. This free event has fun for the whole family with cultural perform… https://t.co/qFIbOasI0P
# neg: 0.0, neu: 0.634, pos: 0.366, compound: 0.8689,
# Update: Collins St passengers may consider William St, Elizabeth St, and Swanston St trams to connect between diverting services.
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Update: Route 48 trams to Victoria Harbour Docklands are diverting via Flinders St between Stop 1 Southern Cross St… https://t.co/ruexGF1myB
# neg: 0.109, neu: 0.891, pos: 0.0, compound: -0.296,
# Due to an emergency services request: Route 11/12/109 trams to Victoria Harbour Docklands/St Kilda/Port Melbourne a… https://t.co/Aiogz0bHQh
# neg: 0.14, neu: 0.86, pos: 0.0, compound: -0.3818,
# Australia's cheeky revenge on stump microphones https://t.co/CuY3aJ83bl #SAvAUS
# neg: 0.327, neu: 0.673, pos: 0.0, compound: -0.5267,
# Building your first Machine Learning model on iPhone https://t.co/AFuKmw3gyA
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Look what I got here, @OReillySecurity ! Maybe finally I’m going to learn this! Congrats for publishing @cchio and… https://t.co/BdW4Bbn3DH
# neg: 0.0, neu: 0.788, pos: 0.212, compound: 0.6792,
# JUMP Bikes is a new bike share program that uses electric assist bikes so you can reach speeds up to 20mph.… https://t.co/wcbBGyoSKU
# neg: 0.0, neu: 0.842, pos: 0.158, compound: 0.3744,
# Why You Need a (Big) Data Management Platform for Your Digital Transformation https://t.co/pvFLJ1wGPK
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @jamesmb: .@Jacob_Rees_Mogg can say what he wants about Sir John Major but, the bottom line is this: John Major is a member of no elite.…
# neg: 0.104, neu: 0.896, pos: 0.0, compound: -0.4215,
# Speech and Interaction Analytics https://t.co/zJHN1TptJn
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @Anna_Soubry: PM’s problem now is 1. Will her #Brexit deal even get off the blocks given EUs clear stance that we won’t get an extensive…
# neg: 0.152, neu: 0.762, pos: 0.086, compound: -0.25,
# RT @Anna_Soubry: Leave voters will listen to PMs wise words on the complexity and cost of #Brexit &amp; increasingly realise they’ve been sold…
# neg: 0.047, neu: 0.83, pos: 0.123, compound: 0.4404,
# RT @jeremycorbyn: After 20 wasted months, Theresa May has again failed to bring clarity to the negotiations - and worryingly, she admitted…
# neg: 0.239, neu: 0.662, pos: 0.099, compound: -0.5859,
# The ALP backbencher who could become a household name https://t.co/tU7DCM83ro #Auspol
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# This MIT study shows how much driving for Uber or Lyft sucks https://t.co/9EbQteJxXc https://t.co/HZ9c4zAyvj
# neg: 0.175, neu: 0.825, pos: 0.0, compound: -0.4144,
# RT @ptv_official: All fixed! Next 5 info is now available again on our app &amp; website. Thanks for your patience.
# neg: 0.0, neu: 0.849, pos: 0.151, compound: 0.4926,
# RT @republicofmath: #FF for #math @CutTheKnotMath @jamestanton @JohnAllenPaulos @GlobalMathProj  @stevenstrogatz @monsoon0  @k8nowak @maano…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Would that be at the Global Math Week 2018 kick-off event on October 6 in San Jose??????!!!!!!! https://t.co/mr3RhzxBgh
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# A framework for automated rating of online reviews against the underlying topics https://t.co/9AAVz9pcwn
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Introduction to Blockchains &amp; What It Means to Big Data https://t.co/f2cM1pLsST
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# The power of https://t.co/KauAaALBgd https://t.co/0jCSGazVjY
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# John McDonald, 1937-2018: @Stanford business professor with illustrious alumni ‘family’ remembered
# https://t.co/menxZ2cuKV
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Great Analysis: Gender Pay Gap in the United States https://t.co/cdWot70BRb
# neg: 0.092, neu: 0.458, pos: 0.451, compound: 0.7579,
# Melbourne Vixens Fan Day is on today. Free activities, giveaways and a pre-season match with the reigning premiers.… https://t.co/Pl86FKDXsY
# neg: 0.0, neu: 0.741, pos: 0.259, compound: 0.6808,
# 90% of customers want to use messaging to talk to businesses, and 80% already use or plan to use #chatbots by 2020.… https://t.co/yUxFPEFYD5
# neg: 0.0, neu: 0.944, pos: 0.056, compound: 0.0772,
# #PrecisionData Is The New #BigData via @datanami https://t.co/IbwS6koZGw
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @curiositydotcom: #Maths #FF: @DrEugeniaCheng @stevenstrogatz @johncarlosbaez @MathforLove @henryseg @Trianglemancsd @SHUmaths
#
# And don'…
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @aatishb: The geometry of clothing is so fascinating... TIL the top end of a sleeve (a sleeve cap) makes a sine curve! Here are two grea…
# neg: 0.0, neu: 0.92, pos: 0.08, compound: 0.2714,
# These rankings are all a bit of fun, but nevertheless, it was fun to see @rmit_csit joint 5th in Australia, accordi… https://t.co/pEHwq7X6Jb
# neg: 0.0, neu: 0.742, pos: 0.258, compound: 0.765,
# 26 Great Blogs Posted in the last 12 Months https://t.co/UovVVWPiEh
# neg: 0.0, neu: 0.687, pos: 0.313, compound: 0.6249,
# An Australian man has broken the 50m freestyle world record in the 100-104 age group https://t.co/OAkdYSHFE7
# neg: 0.165, neu: 0.745, pos: 0.09, compound: -0.34,
# RT @EnserMark: Wow! This might actually tackle teacher workload - especially the significant reduction in contact time. Be interesting to s…
# neg: 0.0, neu: 0.657, pos: 0.343, compound: 0.8347,
# Congratulations to my old @InfoSchoolSheff colleagues: (joint) No 1 on QS World Rankings for Library &amp; Information… https://t.co/xWArPh32Bt
# neg: 0.104, neu: 0.711, pos: 0.185, compound: 0.4019,
# Come to TechCrunch's party and SXSW panels https://t.co/ZMFqtyyWRs by @joshconstine
# neg: 0.0, neu: 0.769, pos: 0.231, compound: 0.4019,
# Air lets you record high-quality home movies without running out of space https://t.co/473gjGidtK by @sarahintampa
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Browse the @WorldBank Global Consumption Database — Data on household consumption patterns in developing countries… https://t.co/j3d8C22WZK
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Metropolitan trains are running to a regular Saturday timetable today. Please check platform displays and refer to… https://t.co/yVhhdsDeXr
# neg: 0.0, neu: 0.874, pos: 0.126, compound: 0.3182,
# What can #proptech offer to Southeast Asia's property sector? - The Asean Post https://t.co/AksnphpxyD https://t.co/kcXKkAb8Hq
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# #BigData Crushers Have Peaked For Now, Regardless Of #Hortonworks' Upcoming Earnings via @SeekingAlpha https://t.co/GtSXkVFYcd
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Yes! The Ankh-Morpork is coming to telly!  #discworld https://t.co/3eZFzKfDj1
# neg: 0.0, neu: 0.709, pos: 0.291, compound: 0.508,
# Non-traditional strategies for mid-career switch to #Datascience and #AI https://t.co/mlaE3dcVAP
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# How data analytics is transforming the Health care industry https://t.co/MqRQVIn1yC
# neg: 0.0, neu: 0.738, pos: 0.262, compound: 0.4939,
# Take pole position at the F1 Grid Festival when it kicks off today at noon. Melbourne's best buskers and DJs, live… https://t.co/QYHDlVowxh
# neg: 0.0, neu: 0.73, pos: 0.27, compound: 0.8126,
# #Melbourne will be feeling the heat today. Check out our top tips for tram travel during hot weather: https://t.co/flREBmJ7Fm
# neg: 0.0, neu: 0.837, pos: 0.163, compound: 0.3182,
# Blockchain will work in trucking -- but only if these three things happen https://t.co/bqPm3p9fXf
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# The coming pokies war  https://t.co/0IE6h5DbGI
# neg: 0.494, neu: 0.506, pos: 0.0, compound: -0.5994,
# “Science subjects can no longer be considered in isolation from the impact of creativity and innovation. A successf… https://t.co/v0g4kSLdTf
# neg: 0.203, neu: 0.581, pos: 0.216, compound: 0.0772,
# ⚠️ Hurstbridge line: Buses replace trains Clifton Hill - Macleod all weekend due to @levelcrossings works.
#
# Info:… https://t.co/L1QL0HNVHS
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# 16 Rules that Helped C-Suite Trust Analytics https://t.co/iH2vkXktED
# neg: 0.0, neu: 0.68, pos: 0.32, compound: 0.5106,
# RT @bcmeconference: #BCME9 full residential tickets are limited! Book your place today and be part of the largest mathematics education con…
# neg: 0.099, neu: 0.901, pos: 0.0, compound: -0.2942,
# “When we hear commentators suggest that university education is now extended to too many people, we should be clear… https://t.co/izHOcSmoVs
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Man shot dead in Sunshine North https://t.co/b41M06bvCr
# neg: 0.344, neu: 0.4, pos: 0.256, compound: -0.2732,
# Discovery of Temporal Neighborhoods through Discretization Methods and Markov Model https://t.co/svhcdM7heD
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# How digital transformation impact the way corporates spread change among their organisations. #FinTech #InsurTech https://t.co/waFlyzstoO
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @doodlers: NEW Drawing Challenge goes live for all! WOOHOO! Spread the news.
# https://t.co/SY3DjBNRhd
# neg: 0.0, neu: 0.67, pos: 0.33, compound: 0.7111,
# #ICO - Vers un nouveau système monétaire international Galvanisé par Internet ? | Assurance &amp; Banque 2.0… https://t.co/GXtyVy1qY5
# neg: 0.0, neu: 0.854, pos: 0.146, compound: 0.34,
# Melburnians urged to test their veggie patches for lead after study finds one-in-five are contaminated https://t.co/IiDezOONo0
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Top IT Training Trends to Watch Out For in 2017 https://t.co/hNTWBwScid
# neg: 0.0, neu: 0.847, pos: 0.153, compound: 0.2023,
# Check out our monthly recommendation of #Free #DataScience #eBooks #dataanalysis https://t.co/qeqzevqS4W https://t.co/tG8TAuMx04
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# How #dataanalysis works for #business via @BizMattersmag https://t.co/036AFPxN9P
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# These electronic skiers hit the slopes in style https://t.co/NOD9NZ4h4H by @johnbiggs
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @kdnuggets: Predicting the 2018 #Oscar Winners with #MachineLearning: Shape Of Water for Best Picture, Guillermo del Toro - Best Directo…
# neg: 0.0, neu: 0.596, pos: 0.404, compound: 0.91,
# RT @sanplaale: But we are all already teaching this!!!, or aren’t we 😒? https://t.co/L25scnIO9m
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Route 6 trams have resumed after an earlier disruption. Delays may occur as we restore normal frequency.
# neg: 0.134, neu: 0.749, pos: 0.118, compound: -0.0772,
# Where Gear Owners Go to Get Insurance https://t.co/7yVCBSBh2B https://t.co/9Epl2CUPpR
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Route 6 trams towards Moreland are delayed due to a traffic incident in High St.
# neg: 0.137, neu: 0.863, pos: 0.0, compound: -0.2263,
# UiPath raising around $120M at $1B+ valuation for its 'software robots' https://t.co/tGhtOI5xaL  by @ingridlunden @sohear
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Worth RP: Given enough data, correct answers jump out at you, right? https://t.co/7KJ3pll99a #bigdata #datascience https://t.co/iooonXtNXQ
# neg: 0.0, neu: 0.888, pos: 0.112, compound: 0.2263,
# Best DSC Forum Questions - Part 1 https://t.co/GcaD9NNE2n
# neg: 0.0, neu: 0.543, pos: 0.457, compound: 0.6369,
# Canada’s 2018 federal budget will arguably be regarded as a positive step for Canadian science – although not as mu… https://t.co/UcqEScDhVW
# neg: 0.088, neu: 0.752, pos: 0.159, compound: 0.3818,
# Deep Learning with TensorFlow in Python https://t.co/emKD3TlT3n
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# Trade action stokes Australian fears of a global recession https://t.co/bkOXiNneeB
# neg: 0.444, neu: 0.556, pos: 0.0, compound: -0.6808,
# How Python &amp; Tableau made an easy Data Analysis of Padma Shri Awards https://t.co/hZUnm48WdB
# neg: 0.0, neu: 0.67, pos: 0.33, compound: 0.7096,
# Dr. @KateCrawford talks about the trouble with bias and explains why bigger data isn’t always better data on the… https://t.co/5t1FdMt6qs
# neg: 0.171, neu: 0.708, pos: 0.121, compound: -0.0516,
# Amazon Prime Video will now slake your thirst for bad but great reality TV https://t.co/qWldo13Ah8 by @etherington https://t.co/D5MDrAtsq6
# neg: 0.093, neu: 0.619, pos: 0.289, compound: 0.6956,
# Another small business complains of counterfeiters on Amazon https://t.co/BdZx1jnKYR
# neg: 0.23, neu: 0.619, pos: 0.15, compound: -0.2263,
# Check out my new #freebook on Amazon! Truth, Lies and #Statistics  https://t.co/GHdTLnDFn3 https://t.co/xP8bNTf4Ol
# neg: 0.164, neu: 0.585, pos: 0.251, compound: 0.126,
# “If we agree that the humanities do not matter, or fail to challenge this assessment, we are colluding in the very… https://t.co/16vMwYuEmy
# neg: 0.122, neu: 0.631, pos: 0.247, compound: 0.5229,
# Route 64 trams have resumed after an earlier disruption. Delays may occur as we restore normal frequency.
# neg: 0.127, neu: 0.761, pos: 0.112, compound: -0.0772,
# TIL: tqdm (the #Python progress bar library) has a specialized "tqdm_notebook" function for use in Jupyter Notebook… https://t.co/ewdlYFqLQD
# neg: 0.0, neu: 0.851, pos: 0.149, compound: 0.4215,
# Le coup d'accélérateur des grands groupes dans le financement des start-up - Les Echos https://t.co/FJfoOApYJQ https://t.co/GLAoK6W37E
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# RT @ScienceTip: Germanium is the only stable element named after a country. The others -- francium, polonium, and americium -- are radioact…
# neg: 0.0, neu: 0.901, pos: 0.099, compound: 0.296,
# When Not to Use Deep Learning https://t.co/IKIdGoxSak
# neg: 0.0, neu: 1.0, pos: 0.0, compound: 0.0,
# FCC Commissioner Mignon Clyburn reiterates need to fight for open internet https://t.co/XF25wYaOIZ by @meganrosedickey
# neg: 0.167, neu: 0.833, pos: 0.0, compound: -0.3818,
# Update - 6.15am:
# - Route 64 trams to Melbourne Uni are delayed due to a traffic incident in Hawthorn Rd.
# - Tow tru… https://t.co/dMcmiELTcC
# neg: 0.091, neu: 0.909, pos: 0.0, compound: -0.2263,

# %%
series = pd.DataFrame(lSentiment, columns=['date', 'sentiment'])
series.set_index('date', inplace=True)
series[['sentiment']] = series[['sentiment']].apply(pd.to_numeric)

series.plot()
plt.show()

series3 = series.resample('1H').sum()
series3.plot()
plt.show()

newSeries = series.resample('1D').sum()
newSeries.plot()
plt.show()
